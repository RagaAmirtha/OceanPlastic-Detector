# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
model = load_model("mobilenet_oceanplastic_detector.keras", compile=False)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
img_path = r"D:\dataset\raw_data\test\plastic\some_image.jpg"

# %%
import os

test_plastic_path = r"D:\dataset\raw_data\test\plastic"
print(os.listdir(test_plastic_path)[:10])
# Out:
# ['plastic (1000).jpg', 'plastic (1001).jpg', 'plastic (1002).jpg', 'plastic (1003).jpg', 'plastic (1004).jpg', 'plastic (1005).jpg', 'plastic (1006).jpg', 'plastic (1007).jpg', 'plastic (1008).jpg', 'plastic (1009).jpg']

# %%
img_path = r"D:\dataset\raw_data\test\plastic\plastic (1000).jpg"

# %%
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
test_plastic_path = r"D:\dataset\raw_data\test\plastic"
first_img = os.listdir(test_plastic_path)[0]
img_path = os.path.join(test_plastic_path, first_img)

print("Using image:", img_path)
# Out:
# Using image: D:\dataset\raw_data\test\plastic\plastic (1000).jpg

# %%
print(os.listdir(test_plastic_path)[:10])
# Out:
# ['plastic (1000).jpg', 'plastic (1001).jpg', 'plastic (1002).jpg', 'plastic (1003).jpg', 'plastic (1004).jpg', 'plastic (1005).jpg', 'plastic (1006).jpg', 'plastic (1007).jpg', 'plastic (1008).jpg', 'plastic (1009).jpg']

# %%
img_path = r"D:\dataset\raw_data\test\plastic\plastic (1000).jpg"
print(img_path)
# Out:
# D:\dataset\raw_data\test\plastic\plastic (1000).jpg

# %%
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
prediction = model.predict(img_array)

if prediction[0][0] > 0.5:
    label = "plastic"
    confidence = prediction[0][0]
else:
    label = "no-plastic"
    confidence = 1 - prediction[0][0]

print("Prediction:", label)
print("Confidence:", round(float(confidence) * 100, 2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Prediction: plastic
# Confidence: 99.99 %

# %%
plt.imshow(img)
plt.title(f"Prediction: {label}")
plt.axis("off")
plt.show()

# %%
test_noplastic_path = r"D:\dataset\raw_data\test\no-plastic"
print(os.listdir(test_noplastic_path)[:10])
# Out:
# ['no_plasic (1000).jpg', 'no_plasic (1001).jpg', 'no_plasic (1002).jpg', 'no_plasic (1003).jpg', 'no_plasic (1004).jpg', 'no_plasic (1005).jpg', 'no_plasic (1006).jpg', 'no_plasic (1007).jpg', 'no_plasic (1008).jpg', 'no_plasic (1009).jpg']

# %%
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
img_path = r"D:\dataset\raw_data\test\no-plastic\no_plasic (1000).jpg"
print(img_path)
# Out:
# D:\dataset\raw_data\test\no-plastic\no_plasic (1000).jpg

# %%
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# %%
prediction = model.predict(img_array)

if prediction[0][0] > 0.5:
    label = "plastic"
    confidence = prediction[0][0]
else:
    label = "no-plastic"
    confidence = 1 - prediction[0][0]

print("Prediction:", label)
print("Confidence:", round(float(confidence) * 100, 2), "%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Prediction: no-plastic
# Confidence: 99.54 %

# %%
plt.imshow(img)
plt.title(f"Prediction: {label}")
plt.axis("off")
plt.show()
